# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
Gemini = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
msg = "What is Google?"
result = Gemini.invoke(msg)
print(result.content)
# Out:
# Google is a **global technology company** that provides a wide range of internet-related services and products. It's one of the largest and most influential companies in the world.
#
# Here's a breakdown of what Google is:
#
# 1.  **A Search Engine:** This is what Google is most famous for. Its search engine is the most widely used in the world, allowing billions of users to find information on the internet quickly and efficiently.
#
# 2.  **A Developer of Other Popular Products & Services:** Google has expanded far beyond just search. Its portfolio includes:
#     *   **Gmail:** A popular email service.
#     *   **Google Maps:** A mapping and navigation service.
#     *   **YouTube:** The world's largest video-sharing platform (owned by Google).
#     *   **Android:** The most widely used mobile operating system in the world.
#     *   **Google Chrome:** A leading web browser.
#     *   **Google Drive:** Cloud storage and productivity tools (Docs, Sheets, Slides).
#     *   **Google Photos:** Photo storage and management.
#     *   **Google Cloud:** A suite of cloud computing services for businesses.
#     *   **Google Assistant:** An AI-powered virtual assistant.
#
# 3.  **A Hardware Manufacturer:** Google also produces its own hardware, including:
#     *   **Pixel phones:** Its flagship smartphones.
#     *   **Google Nest devices:** Smart home products like speakers, displays, and thermostats.
#     *   **Chromebooks:** Laptops running its Chrome OS.
#
# 4.  **An Advertising Powerhouse:** Google's primary revenue source comes from advertising. It sells ad space on its search results, YouTube, and across a vast network of websites and apps.
#
# 5.  **A Subsidiary of Alphabet Inc.:** In 2015, Google restructured its operations, forming a new parent company called **Alphabet Inc.** Google itself became the main subsidiary of Alphabet, encompassing its core internet products (search, ads, Android, Chrome, YouTube, Maps, etc.). This allowed Alphabet to manage its "other bets" (like Waymo for self-driving cars, Verily for life sciences, etc.) as separate entities, while keeping Google focused on its internet services.
#
# In essence, Google's mission is "to organize the world's information and make it universally accessible and useful." It has become an indispensable part of daily life for billions of people globally, touching almost every aspect of how we access information, communicate, and interact with technology.

# %%
msg1 = "What is LangChain?"
result1 = Gemini.invoke(msg1)
print(result1.content)
# Out:
# **LangChain** is an open-source framework designed to simplify the development of applications powered by Large Language Models (LLMs).
#
# Think of it as a set of tools and a structured way to build more complex and capable applications *on top of* foundational LLMs like GPT-4, Claude, Llama 2, etc. LangChain itself is **not an LLM**; rather, it's a library that helps you connect and orchestrate various components to make LLMs much more useful and powerful in real-world scenarios.
#
# Here's a breakdown of what LangChain is and why it's important:
#
# ### What Problem Does LangChain Solve?
#
# While LLMs are incredibly powerful at generating text, answering questions, and understanding context, they have limitations when used in isolation for complex applications:
#
# 1.  **Limited Context Window:** They can only process so much information at once.
# 2.  **Lack of External Knowledge:** They only know what they were trained on; they can't access real-time data, specific company documents, or use external tools.
# 3.  **Single-Turn Interactions:** Many applications require multi-step reasoning, memory of past conversations, or chaining together multiple actions.
# 4.  **Integration Complexity:** Connecting LLMs to different data sources, APIs, and other models can be cumbersome.
#
# LangChain provides the "glue" and "intelligence" to overcome these limitations.
#
# ### Key Concepts and Components of LangChain:
#
# LangChain is built around several modular components that can be combined in various ways:
#
# 1.  **Models (LLMs, ChatModels, Embeddings):**
#     *   **LLMs:** Integrates with various large language models (e.g., OpenAI, Hugging Face, Anthropic) to send prompts and get text completions.
#     *   **ChatModels:** Optimized for conversational interactions, often returning structured messages rather than just raw text.
#     *   **Embeddings:** Generates numerical representations of text, crucial for tasks like similarity search and retrieval.
#
# 2.  **Prompts:**
#     *   Manages the process of constructing effective prompts for LLMs. This includes prompt templates, examples, and parsers for output.
#
# 3.  **Chains:**
#     *   The core concept! Chains allow you to combine different components (LLMs, other chains, tools) in a predetermined sequence to accomplish a specific task. For example, a chain could retrieve data, then summarize it, then answer a user's question based on the summary.
#
# 4.  **Retrieval:**
#     *   Enables applications to augment LLMs with external data (e.g., your documents, a database, the web). This is vital for **Retrieval-Augmented Generation (RAG)**, where an LLM's knowledge is supplemented with relevant, up-to-date, or proprietary information.
#     *   Components include document loaders, text splitters, vector stores, and retrievers.
#
# 5.  **Agents:**
#     *   Takes chaining a step further by allowing the LLM to dynamically decide *which tools* to use and *in what order* to achieve a goal. An agent essentially acts as a "reasoning engine" that can observe, decide, and act.
#     *   Tools could be a search engine, a calculator, an API call, a Python interpreter, etc.
#
# 6.  **Memory:**
#     *   Adds state to chains and agents, allowing them to remember past interactions in a conversation. This is essential for building natural and coherent chatbots.
#
# ### Why Use LangChain?
#
# *   **Simplifies Complexity:** Abstracts away much of the boilerplate code and complexity involved in building LLM-powered applications.
# *   **Accelerates Development:** Provides ready-to-use components and patterns, allowing developers to build sophisticated apps faster.
# *   **Modularity and Flexibility:** Components are interchangeable, allowing you to easily swap out LLMs, data sources, or tools.
# *   **Enables Advanced Use Cases:** Makes it feasible to build applications that go beyond simple text generation, incorporating external knowledge, multi-step reasoning, and interaction with tools.
# *   **Community and Ecosystem:** Being open-source, it has a large community and integrates with a wide range of other technologies.
#
# ### Common Use Cases:
#
# *   **Question Answering over Custom Documents (RAG):** Build a chatbot that can answer questions based on your company's internal knowledge base, legal documents, or research papers.
# *   **Intelligent Chatbots:** Create chatbots that can remember past conversations, perform actions (like booking a meeting via an API), or look up real-time information.
# *   **Autonomous Agents:** Develop agents that can perform multi-step tasks, like researching a topic, summarizing findings, and generating a report.
# *   **Data Extraction and Transformation:** Use LLMs to extract structured information from unstructured text or convert data between formats.
# *   **Code Generation and Debugging:** Leverage agents with code interpreters to write, test, and debug code.
#
# In essence, LangChain is a crucial framework for moving beyond basic LLM prompts to construct sophisticated, context-aware, and interactive AI applications. It's available primarily in **Python** and **JavaScript/TypeScript**.
